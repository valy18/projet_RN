# %% [markdown]
# ### `Prédiction des LAI, LEAF_LENGTH et LEAF_WIDTH`
#
# 1. Chargement des librairies et packages

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder,LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout

# %% [markdown]
# 2. Chargement des données

# %%
# Installer openpyxl


# Charger les données
file_path = './Gombo_Observations_etiquettesV0.5.xlsx'
df = pd.read_excel(file_path, sheet_name="Etiquettes_2 (2)")

# %% [markdown]
# 3. Analyse exploratoire et descriptive

# %%
#Aperçu 

df.head(10)
# Out:
#   Acquisition Session  DAS Treatment  LEAF_LENGTH  LEAF_WIDTH       LAI  \
# 0                 AS1    8        T1           15          15    1.6875
# 1                 AS1    8        T1           12          12    1.0800
# 2                 AS1    8        T1           18          18    2.4300
# 3                 AS1    8        T1           18          15    2.0250
# 4                 AS9   40        T1          140         143  150.1500
# 5                 AS9   40        T1          140         145  152.2500
# 6                 AS9   40        T1          103          97   74.9325
# 7                 AS9   40        T1           95          91   64.8375
# 8                 AS9   40        T1           55          61   25.1625
# 9                 AS9   40        T1           55          47   19.3875
#
#    LEAF_NUMBER  PLANT_HEIGHT  STEM_DIAMETER      RF_U  ...      PSRI  \
# 0          2.0          70.0            1.0  0.941167  ...  0.011238
# 1          2.0         100.0            1.0  0.744238  ...  0.021673
# 2          2.0          80.0            1.0  0.851200  ...  0.009550
# 3          2.0         120.0            1.0  0.941167  ...  0.011238
# 4         10.0         430.0            5.0  0.902224  ...  0.023126
# 5          8.0         540.0            5.0  0.966109  ...  0.010328
# 6          8.0         540.0            5.0  0.820931  ...  0.004772
# 7         10.0         430.0            5.5  0.902224  ...  0.023126
# 8          9.0         590.0            6.0  0.966109  ...  0.010328
# 9          9.0         550.0            6.0  0.543862  ...  0.009123
#
#           ARI       dBE    BEIP   Sum_dBE       dYE   Sum_dYE      PhRI  \
# 0   98.736618  0.000181  520.48  0.023660 -0.000008 -0.012776  0.094210
# 1   14.671596  0.000109  522.74  0.014060  0.000005 -0.005068  0.016501
# 2  129.747527  0.000153  521.51  0.019626  0.000008 -0.009159  0.120737
# 3   98.736618  0.000181  520.48  0.023660 -0.000008 -0.012776  0.094210
# 4   18.993673  0.000336  522.13  0.040890 -0.000008 -0.023103  0.054280
# 5   75.801243  0.000246  520.89  0.031391 -0.000014 -0.018244  0.101764
# 6   34.753011  0.000424  521.30  0.052414 -0.000026 -0.031791  0.104747
# 7   18.993673  0.000336  522.13  0.040890 -0.000008 -0.023103  0.054280
# 8   75.801243  0.000246  520.89  0.031391 -0.000014 -0.018244  0.101764
# 9    6.972464  0.000831  520.68  0.102649 -0.000048 -0.060393  0.065020
#
#          TVI      RVSI
# 0  12.518276  0.019140
# 1  11.297272  0.016846
# 2  12.832241  0.018810
# 3  12.518276  0.019140
# 4  14.367230  0.015359
# 5  14.336211  0.019098
# 6  17.487941  0.015643
# 7  14.367230  0.015359
# 8  14.336211  0.019098
# 9  18.614820 -0.002932
#
# [10 rows x 118 columns]

# %%
#Dimension
df.shape
# Out:
# (2048, 118)

# %%
#Type des colonnes
df.dtypes
# Out:
# Acquisition Session     object
# DAS                      int64
# Treatment               object
# LEAF_LENGTH              int64
# LEAF_WIDTH               int64
#                         ...
# dYE                    float64
# Sum_dYE                float64
# PhRI                   float64
# TVI                    float64
# RVSI                   float64
# Length: 118, dtype: object

# %% [markdown]
# * On souhaite avoir les colonnes de types `object` afin de les encoder avant la mise en place du modèle

# %%
# Extraire les colonnes de type object
object_columns = df.select_dtypes(include=['object'])

# Afficher les colonnes de type object
print("Colonnes de type object :")
print(object_columns.columns.tolist())

# Optionnel : Afficher un aperçu des données
print("\nAperçu des colonnes de type object :")
print(object_columns.head())
# Out:
# Colonnes de type object :
# ['Acquisition Session', 'Treatment']
#
# Aperçu des colonnes de type object :
#   Acquisition Session Treatment
# 0                 AS1        T1
# 1                 AS1        T1
# 2                 AS1        T1
# 3                 AS1        T1
# 4                 AS9        T1

# %% [markdown]
# * Valeurs manquantes

# %%
# Identifier les colonnes avec des valeurs manquantes
missing_columns = df.columns[df.isnull().any()]

# Afficher les colonnes avec valeurs manquantes et leur nombre
print("Colonnes avec des valeurs manquantes :")
for col in missing_columns:
    print(f"{col}: {df[col].isnull().sum()} valeur(s) manquante(s)")
# Out:
# Colonnes avec des valeurs manquantes :
# LEAF_NUMBER: 1 valeur(s) manquante(s)
# PLANT_HEIGHT: 1 valeur(s) manquante(s)
# STEM_DIAMETER: 1 valeur(s) manquante(s)

# %% [markdown]
# * Imputation

# %%
# Imputer les valeurs manquantes par la moyenne de chaque colonne
for col in missing_columns:
    mean_value = df[col].mean()  # Calculer la moyenne
    df[col].fillna(mean_value, inplace=True)  # Remplacer les NaN par la moyenne

# Vérifier qu'il n'y a plus de valeurs manquantes
print("Nombre total de valeurs manquantes après imputation :")
print(df.isnull().sum().sum())
# Out:
# Nombre total de valeurs manquantes après imputation :
# 0
# C:\Users\COULIBALYPEKANRIKADI\AppData\Local\Temp\ipykernel_11092\1302663659.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(mean_value, inplace=True)  # Remplacer les NaN par la moyenne

# %%
#Voir les repartitions des colonnes
df.describe().T
# Out:
#               count       mean        std       min        25%        50%  \
# DAS          2048.0  40.417969  14.238018  8.000000  28.000000  40.000000
# LEAF_LENGTH  2048.0  82.447754  53.990764  2.000000  35.000000  78.000000
# LEAF_WIDTH   2048.0  80.851562  54.087803  2.000000  33.000000  75.000000
# LAI          2048.0  71.767665  76.225798  0.030000   8.662500  45.000000
# LEAF_NUMBER  2048.0  10.219834   2.874264  2.000000   8.000000  11.000000
# ...             ...        ...        ...       ...        ...        ...
# dYE          2048.0  -0.000070   0.000067 -0.000242  -0.000109  -0.000067
# Sum_dYE      2048.0  -0.221808   0.083847 -0.497871  -0.270262  -0.224214
# PhRI         2048.0   0.073371   0.033536  0.010582   0.046009   0.072678
# TVI          2048.0  50.878909  11.533686  9.476849  45.309731  54.614441
# RVSI         2048.0  -0.078900   0.035750 -0.185158  -0.100297  -0.086779
#
#                     75%         max
# DAS           52.000000   64.000000
# LEAF_LENGTH  125.000000  230.000000
# LEAF_WIDTH   125.000000  225.000000
# LAI          119.062500  388.125000
# LEAF_NUMBER   13.000000   15.000000
# ...                 ...         ...
# dYE           -0.000033    0.000312
# Sum_dYE       -0.176880   -0.005068
# PhRI           0.107873    0.125578
# TVI           59.690544   67.000143
# RVSI          -0.062221    0.023070
#
# [116 rows x 8 columns]

# %% [markdown]
# 4. Modélisation

# %%
#Encodage : Appliquer Label Encoding sur chaque colonne catégorique
label_encoder = LabelEncoder()
for col in object_columns:
    df[col] = label_encoder.fit_transform(df[col])

df.head(5)
# Out:
#    Acquisition Session  DAS  Treatment  LEAF_LENGTH  LEAF_WIDTH       LAI  \
# 0                    0    8          0           15          15    1.6875
# 1                    0    8          0           12          12    1.0800
# 2                    0    8          0           18          18    2.4300
# 3                    0    8          0           18          15    2.0250
# 4                   14   40          0          140         143  150.1500
#
#    LEAF_NUMBER  PLANT_HEIGHT  STEM_DIAMETER      RF_U  ...      PSRI  \
# 0          2.0          70.0            1.0  0.941167  ...  0.011238
# 1          2.0         100.0            1.0  0.744238  ...  0.021673
# 2          2.0          80.0            1.0  0.851200  ...  0.009550
# 3          2.0         120.0            1.0  0.941167  ...  0.011238
# 4         10.0         430.0            5.0  0.902224  ...  0.023126
#
#           ARI       dBE    BEIP   Sum_dBE       dYE   Sum_dYE      PhRI  \
# 0   98.736618  0.000181  520.48  0.023660 -0.000008 -0.012776  0.094210
# 1   14.671596  0.000109  522.74  0.014060  0.000005 -0.005068  0.016501
# 2  129.747527  0.000153  521.51  0.019626  0.000008 -0.009159  0.120737
# 3   98.736618  0.000181  520.48  0.023660 -0.000008 -0.012776  0.094210
# 4   18.993673  0.000336  522.13  0.040890 -0.000008 -0.023103  0.054280
#
#          TVI      RVSI
# 0  12.518276  0.019140
# 1  11.297272  0.016846
# 2  12.832241  0.018810
# 3  12.518276  0.019140
# 4  14.367230  0.015359
#
# [5 rows x 118 columns]

# %%
# Variables cibles (outputs) et entrées (features)
target_columns = ["LAI", "LEAF_LENGTH", "LEAF_WIDTH"]
X = df.drop(columns=target_columns)
y = df[target_columns]

# %%
# Normalisation des données
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

scaler_y = StandardScaler()
y_scaled = scaler_y.fit_transform(y)

# %%
# Séparer en jeu d'entraînement et de test
seed = 2025
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=seed)

# Reshaper pour le RNN
X_train_rnn = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_rnn = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# %%
# Construire le modèle RNN
model = Sequential()
model.add(SimpleRNN(64, activation='relu', input_shape=(1, X_train.shape[1])))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(3, activation='linear'))  # 3 sorties pour les cibles LAI, LEAF_LENGTH, LEAF_WIDTH
# Out:
# c:\Users\COULIBALYPEKANRIKADI\cpkv\ECOLE\INP\M2\MOI\RN\projet\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │        11,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,699 (53.51 KB)
#  Trainable params: 13,699 (53.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compiler le modèle
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
# Entraîner le modèle
history = model.fit(X_train_rnn, y_train, epochs=100, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1.2795 - mae: 0.9209 - val_loss: 0.9839 - val_mae: 0.8213
# Epoch 2/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9858 - mae: 0.8268 - val_loss: 0.9061 - val_mae: 0.7804
# Epoch 3/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8560 - mae: 0.7535 - val_loss: 0.8505 - val_mae: 0.7463
# Epoch 4/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7511 - mae: 0.7014 - val_loss: 0.8175 - val_mae: 0.7237
# Epoch 5/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7714 - mae: 0.7012 - val_loss: 0.8269 - val_mae: 0.7261
# Epoch 6/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7173 - mae: 0.6744 - val_loss: 0.8027 - val_mae: 0.7081
# Epoch 7/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7172 - mae: 0.6646 - val_loss: 0.7887 - val_mae: 0.7020
# Epoch 8/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6945 - mae: 0.6549 - val_loss: 0.7836 - val_mae: 0.6996
# Epoch 9/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6616 - mae: 0.6400 - val_loss: 0.7841 - val_mae: 0.6892
# Epoch 10/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7130 - mae: 0.6667 - val_loss: 0.7858 - val_mae: 0.6826
# Epoch 11/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7260 - mae: 0.6673 - val_loss: 0.7780 - val_mae: 0.6903
# Epoch 12/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6956 - mae: 0.6513 - val_loss: 0.7799 - val_mae: 0.6872
# Epoch 13/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6625 - mae: 0.6305 - val_loss: 0.7717 - val_mae: 0.6835
# Epoch 14/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6561 - mae: 0.6216 - val_loss: 0.7759 - val_mae: 0.6781
# Epoch 15/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6902 - mae: 0.6408 - val_loss: 0.7764 - val_mae: 0.6775
# Epoch 16/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6415 - mae: 0.6117 - val_loss: 0.7648 - val_mae: 0.6757
# Epoch 17/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6477 - mae: 0.6303 - val_loss: 0.7709 - val_mae: 0.6804
# Epoch 18/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6403 - mae: 0.6211 - val_loss: 0.7625 - val_mae: 0.6738
# Epoch 19/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6208 - mae: 0.6094 - val_loss: 0.7726 - val_mae: 0.6841
# Epoch 20/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6369 - mae: 0.6188 - val_loss: 0.7738 - val_mae: 0.6803
# Epoch 21/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6187 - mae: 0.6130 - val_loss: 0.8068 - val_mae: 0.7048
# Epoch 22/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6668 - mae: 0.6342 - val_loss: 0.7756 - val_mae: 0.6913
# Epoch 23/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6342 - mae: 0.6175 - val_loss: 0.7732 - val_mae: 0.6820
# Epoch 24/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6605 - mae: 0.6192 - val_loss: 0.7752 - val_mae: 0.6831
# Epoch 25/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6615 - mae: 0.6295 - val_loss: 0.7689 - val_mae: 0.6801
# Epoch 26/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6558 - mae: 0.6346 - val_loss: 0.7754 - val_mae: 0.6800
# Epoch 27/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6724 - mae: 0.6270 - val_loss: 0.7638 - val_mae: 0.6788
# Epoch 28/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6714 - mae: 0.6406 - val_loss: 0.7651 - val_mae: 0.6737
# Epoch 29/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5832 - mae: 0.5906 - val_loss: 0.8251 - val_mae: 0.7109
# Epoch 30/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6493 - mae: 0.6307 - val_loss: 0.7839 - val_mae: 0.6827
# Epoch 31/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6179 - mae: 0.6025 - val_loss: 0.7962 - val_mae: 0.6902
# Epoch 32/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6656 - mae: 0.6332 - val_loss: 0.7858 - val_mae: 0.6875
# Epoch 33/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6141 - mae: 0.6072 - val_loss: 0.8014 - val_mae: 0.6940
# Epoch 34/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6485 - mae: 0.6229 - val_loss: 0.7615 - val_mae: 0.6731
# Epoch 35/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6783 - mae: 0.6358 - val_loss: 0.7678 - val_mae: 0.6781
# Epoch 36/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6516 - mae: 0.6148 - val_loss: 0.7773 - val_mae: 0.6865
# Epoch 37/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6432 - mae: 0.6167 - val_loss: 0.7872 - val_mae: 0.6852
# Epoch 38/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6214 - mae: 0.6037 - val_loss: 0.7704 - val_mae: 0.6816
# Epoch 39/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6477 - mae: 0.6246 - val_loss: 0.7738 - val_mae: 0.6770
# Epoch 40/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.7010 - mae: 0.6392 - val_loss: 0.7826 - val_mae: 0.6846
# Epoch 41/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6642 - mae: 0.6209 - val_loss: 0.7686 - val_mae: 0.6786
# Epoch 42/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6444 - mae: 0.6235 - val_loss: 0.7754 - val_mae: 0.6843
# Epoch 43/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6001 - mae: 0.5939 - val_loss: 0.7854 - val_mae: 0.6802
# Epoch 44/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6574 - mae: 0.6271 - val_loss: 0.7583 - val_mae: 0.6766
# Epoch 45/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6234 - mae: 0.6099 - val_loss: 0.7974 - val_mae: 0.6915
# Epoch 46/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6419 - mae: 0.6176 - val_loss: 0.7885 - val_mae: 0.6862
# Epoch 47/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6012 - mae: 0.5985 - val_loss: 0.7786 - val_mae: 0.6863
# Epoch 48/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6151 - mae: 0.6102 - val_loss: 0.7777 - val_mae: 0.6746
# Epoch 49/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6417 - mae: 0.6140 - val_loss: 0.7738 - val_mae: 0.6809
# Epoch 50/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5904 - mae: 0.5887 - val_loss: 0.7840 - val_mae: 0.6887
# Epoch 51/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6236 - mae: 0.6114 - val_loss: 0.8139 - val_mae: 0.7022
# Epoch 52/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6315 - mae: 0.6153 - val_loss: 0.7938 - val_mae: 0.6882
# Epoch 53/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6973 - mae: 0.6445 - val_loss: 0.7824 - val_mae: 0.6737
# Epoch 54/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6223 - mae: 0.5904 - val_loss: 0.7728 - val_mae: 0.6847
# Epoch 55/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6572 - mae: 0.6267 - val_loss: 0.7779 - val_mae: 0.6844
# Epoch 56/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5950 - mae: 0.5902 - val_loss: 0.7895 - val_mae: 0.6867
# Epoch 57/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6770 - mae: 0.6388 - val_loss: 0.7623 - val_mae: 0.6802
# Epoch 58/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6466 - mae: 0.6151 - val_loss: 0.7748 - val_mae: 0.6781
# Epoch 59/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6207 - mae: 0.6082 - val_loss: 0.7808 - val_mae: 0.6792
# Epoch 60/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5919 - mae: 0.5863 - val_loss: 0.7691 - val_mae: 0.6850
# Epoch 61/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5864 - mae: 0.5863 - val_loss: 0.7857 - val_mae: 0.6874
# Epoch 62/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6179 - mae: 0.6116 - val_loss: 0.7778 - val_mae: 0.6866
# Epoch 63/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6295 - mae: 0.6115 - val_loss: 0.7769 - val_mae: 0.6804
# Epoch 64/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6288 - mae: 0.5978 - val_loss: 0.7750 - val_mae: 0.6830
# Epoch 65/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5783 - mae: 0.5855 - val_loss: 0.7913 - val_mae: 0.6867
# Epoch 66/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6028 - mae: 0.5910 - val_loss: 0.7858 - val_mae: 0.6897
# Epoch 67/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6237 - mae: 0.6154 - val_loss: 0.7757 - val_mae: 0.6813
# Epoch 68/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6377 - mae: 0.6131 - val_loss: 0.7793 - val_mae: 0.6790
# Epoch 69/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6363 - mae: 0.6105 - val_loss: 0.8157 - val_mae: 0.6942
# Epoch 70/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7043 - mae: 0.6444 - val_loss: 0.7646 - val_mae: 0.6695
# Epoch 71/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6438 - mae: 0.6141 - val_loss: 0.7742 - val_mae: 0.6732
# Epoch 72/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6504 - mae: 0.6232 - val_loss: 0.7902 - val_mae: 0.6765
# Epoch 73/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6648 - mae: 0.6154 - val_loss: 0.7945 - val_mae: 0.6875
# Epoch 74/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6201 - mae: 0.5954 - val_loss: 0.7893 - val_mae: 0.6887
# Epoch 75/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5942 - mae: 0.5871 - val_loss: 0.7892 - val_mae: 0.6929
# Epoch 76/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6260 - mae: 0.6156 - val_loss: 0.7699 - val_mae: 0.6724
# Epoch 77/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6046 - mae: 0.5934 - val_loss: 0.7848 - val_mae: 0.6863
# Epoch 78/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5970 - mae: 0.5892 - val_loss: 0.7957 - val_mae: 0.6892
# Epoch 79/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6237 - mae: 0.6032 - val_loss: 0.8046 - val_mae: 0.6989
# Epoch 80/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6080 - mae: 0.5983 - val_loss: 0.8025 - val_mae: 0.6902
# Epoch 81/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5804 - mae: 0.5726 - val_loss: 0.7719 - val_mae: 0.6811
# Epoch 82/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6061 - mae: 0.5918 - val_loss: 0.7885 - val_mae: 0.6910
# Epoch 83/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5628 - mae: 0.5755 - val_loss: 0.7791 - val_mae: 0.6865
# Epoch 84/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6377 - mae: 0.6151 - val_loss: 0.7878 - val_mae: 0.6831
# Epoch 85/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6151 - mae: 0.5964 - val_loss: 0.7735 - val_mae: 0.6808
# Epoch 86/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6404 - mae: 0.6162 - val_loss: 0.7779 - val_mae: 0.6752
# Epoch 87/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6529 - mae: 0.6114 - val_loss: 0.7963 - val_mae: 0.6916
# Epoch 88/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6468 - mae: 0.6213 - val_loss: 0.7785 - val_mae: 0.6803
# Epoch 89/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6683 - mae: 0.6217 - val_loss: 0.7848 - val_mae: 0.6773
# Epoch 90/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6382 - mae: 0.6055 - val_loss: 0.7836 - val_mae: 0.6831
# Epoch 91/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6042 - mae: 0.5901 - val_loss: 0.7876 - val_mae: 0.6861
# Epoch 92/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5933 - mae: 0.5910 - val_loss: 0.7983 - val_mae: 0.6889
# Epoch 93/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6345 - mae: 0.6021 - val_loss: 0.8061 - val_mae: 0.6968
# Epoch 94/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6200 - mae: 0.6009 - val_loss: 0.7856 - val_mae: 0.6839
# Epoch 95/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6027 - mae: 0.5873 - val_loss: 0.7713 - val_mae: 0.6776
# Epoch 96/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5917 - mae: 0.5859 - val_loss: 0.7842 - val_mae: 0.6908
# Epoch 97/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6249 - mae: 0.6063 - val_loss: 0.7805 - val_mae: 0.6810
# Epoch 98/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6404 - mae: 0.6086 - val_loss: 0.8004 - val_mae: 0.6952
# Epoch 99/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6546 - mae: 0.6156 - val_loss: 0.7844 - val_mae: 0.6815
# Epoch 100/100
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6044 - mae: 0.5999 - val_loss: 0.7787 - val_mae: 0.6834

# %%
# Évaluer le modèle
loss, mae = model.evaluate(X_test_rnn, y_test)
print(f"Test Loss: {loss}, Test MAE: {mae}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7929 - mae: 0.6794
# Test Loss: 0.8367147445678711, Test MAE: 0.7008740901947021

# %%
# Faire des prédictions
y_pred_scaled = model.predict(X_test_rnn)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step

# %%
# Revenir aux échelles d'origine pour les prédictions
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test_original = scaler_y.inverse_transform(y_test)

# Afficher quelques résultats de prédiction
for i in range(5):
    print(f"Réel : {y_test_original[i]}, Prédit : {y_pred[i]}")
# Out:
# Réel : [ 79.5675 103.     103.    ], Prédit : [53.2626   74.781944 73.22886 ]
# Réel : [25.65 57.   60.  ], Prédit : [74.42056  93.632545 90.01536 ]
# Réel : [58.725 87.    90.   ], Prédit : [52.98877 74.32013 72.80621]
# Réel : [ 94.08 112.   112.  ], Prédit : [ 93.58572  101.365715 100.21432 ]
# Réel : [28.8 64.  60. ], Prédit : [81.64985  92.20723  91.708664]
